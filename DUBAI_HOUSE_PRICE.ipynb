# %% [markdown]
# <a href="https://colab.research.google.com/github/myra573/MeeraS/blob/main/DUBAI_HOUSE_PRICE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df= pd.read_csv("/housing_price_dataset.csv")

# %%
df_cleaned = df.dropna()

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %%
df.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325151
# std      575.513241      1.116326      0.815851     20.719377   76141.842966
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.165397
# 25%     1513.000000      3.000000      1.000000   1967.000000  169955.860225
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.141166
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.630052
# max     2999.000000      5.000000      3.000000   2021.000000  492195.259972

# %%
df_cleaned=df.drop_duplicates()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df['price_per_square_feet'] = df.apply(lambda row: row.Price/row.SquareFeet, axis=1)
df['property_age'] = df.apply(lambda row: 2025-row.YearBuilt, axis=1)

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price  \
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065
#
#    price_per_square_feet  property_age
# 0             101.295994            56
# 1              79.306312            45
# 2             164.995168            55
# 3              90.142453            29
# 4             127.904338            24

# %%
df.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price  \
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325151
# std      575.513241      1.116326      0.815851     20.719377   76141.842966
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.165397
# 25%     1513.000000      3.000000      1.000000   1967.000000  169955.860225
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.141166
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.630052
# max     2999.000000      5.000000      3.000000   2021.000000  492195.259972
#
#        price_per_square_feet  property_age
# count           50000.000000  50000.000000
# mean              113.305052     39.595580
# std                29.318791     20.719377
# min               -36.118623      4.000000
# 25%                94.830863     22.000000
# ...

# %%
df['listing_category'] = pd.qcut(df['Price'], q=[0, .25, .75, 1], labels=['Budget', 'Mid_range', 'High_end'])

# %%
df['price_per_square_feet'] = df['price_per_square_feet'].astype('int')
df['property_age'] = df['property_age'].astype('int')
df['listing_category'] = df['listing_category'].astype('str')

# %%
df.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price  \
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325151
# std      575.513241      1.116326      0.815851     20.719377   76141.842966
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.165397
# 25%     1513.000000      3.000000      1.000000   1967.000000  169955.860225
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.141166
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.630052
# max     2999.000000      5.000000      3.000000   2021.000000  492195.259972
#
#        price_per_square_feet  property_age
# count           50000.000000  50000.000000
# mean              112.806020     39.595580
# std                29.318432     20.719377
# min               -36.000000      4.000000
# 25%                94.000000     22.000000
# ...

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price  \
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065
#
#    price_per_square_feet  property_age listing_category
# 0                    101            56        Mid_range
# 1                     79            45        Mid_range
# 2                    164            55         High_end
# 3                     90            29        Mid_range
# 4                    127            24        Mid_range

# %%
def write_google_sheet(df, sheet_name):
    # gc is not defined here, you'll need to import and initialize a library like gspread for Google Sheets interaction.
    # For example:
    # import gspread
    # gc = gspread.service_account()
    sh = gc.create(housing_price_dataset.csv)
    worksheet = gc.open(housing_price_dataset.csv).sheet1
    worksheet.append_rows([df.columns.values.tolist()] + df.values.tolist())
    # worksheet.update([df.columns.values.tolist()] + df.values.tolist())
    print(worksheet.get_all_records())

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price  \
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065
#
#    price_per_square_feet  property_age listing_category
# 0                    101            56        Mid_range
# 1                     79            45        Mid_range
# 2                    164            55         High_end
# 3                     90            29        Mid_range
# 4                    127            24        Mid_range
